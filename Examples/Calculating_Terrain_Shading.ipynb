# %%
from pathlib import Path
import os
from datetime import datetime

# %%
pckg_pth = Path('..')
os.chdir(pckg_pth)

import insolpy

# %%
insolpy.pyramid(100)
# Out:
# array([[0, 0, 0, ..., 0, 0, 0],
#        [0, 1, 2, ..., 2, 1, 0],
#        [0, 2, 4, ..., 4, 2, 0],
#        ...,
#        [0, 2, 4, ..., 4, 2, 0],
#        [0, 1, 2, ..., 2, 1, 0],
#        [0, 0, 0, ..., 0, 0, 0]])
